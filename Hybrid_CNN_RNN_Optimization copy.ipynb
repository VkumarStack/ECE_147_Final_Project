# %%
import utils
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.layers import Conv1D, MaxPool1D, Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape, TimeDistributed, Input, GRU, Bidirectional
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
# Load the Dataset

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

y_train_valid -= 769
y_test -= 769
# Out:
# (2115, 22, 1000)

# %%
ind_valid = np.random.choice(2115, 200, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))
(x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid]
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]

# Shuffle the data after adding the noise to them so that the noisy examples 
# are not all together
x_train, y_train = utils.addNoisyExamplesToData(x_train, y_train, 6000, 0, 1)

indices = np.random.permutation(len(x_train))
x_train = x_train[indices]
y_train = y_train[indices]
print(x_train.shape)
print(y_train.shape)

y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)

# Reshape so that each example is three-dimensional 
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_valid.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# Axis swapping
x_train = np.swapaxes(x_train, 1, 3)
x_train = np.swapaxes(x_train, 1, 2)
x_valid = np.swapaxes(x_valid, 1, 3)
x_valid = np.swapaxes(x_valid, 1, 2)
X_test = np.swapaxes(X_test, 1, 3)
X_test = np.swapaxes(X_test, 1, 2)

x_train = x_train[:, 0:600, :, :]
x_valid = x_valid[:, 0:600, :, :]
X_test = X_test[:, 0:600, :, :]
print(x_train.shape)
# Out:
# (7915, 22, 1000)
# (7915,)
# (7915, 600, 1, 22)

# %%
hybrid_model = Sequential()

# Given that this is time-series data, having a kernel that is more along one dimension (e.g. 15 by 1) is reasonable
# since there is not really much of a relationship between "square" tiles of the data but rather subsequent 
# tiles
hybrid_model.add(Conv2D(filters=20, kernel_size=(15, 1), padding='same', activation='relu', input_shape=(600, 1, 22)))
hybrid_model.add(MaxPooling2D(pool_size=(3, 1), padding='same'))
hybrid_model.add(BatchNormalization())
hybrid_model.add(Dropout(0.4))

hybrid_model.add(Conv2D(filters=40, kernel_size=(10, 1), padding='same', activation='relu'))
hybrid_model.add(MaxPooling2D(pool_size=(3, 1), padding='same'))
hybrid_model.add(BatchNormalization())
hybrid_model.add(Dropout(0.4))

hybrid_model.add(Conv2D(filters=60, kernel_size=(5, 1), padding='same', activation='relu'))
hybrid_model.add(MaxPooling2D(pool_size=(3, 1), padding='same'))
hybrid_model.add(BatchNormalization())
hybrid_model.add(Dropout(0.4))

hybrid_model.add(Conv2D(filters=100, kernel_size=(5, 1), padding='same', activation='relu'))
hybrid_model.add(MaxPooling2D(pool_size=(3, 1), padding='same'))
hybrid_model.add(BatchNormalization())
hybrid_model.add(Dropout(0.4))


hybrid_model.add(TimeDistributed(Flatten()))
hybrid_model.add(TimeDistributed(Dense(40, activation='relu')))
hybrid_model.add(TimeDistributed(BatchNormalization()))
hybrid_model.add(TimeDistributed(Dropout(0.4)))

hybrid_model.add(LSTM(8, dropout=0.4, recurrent_dropout=0.1, return_sequences=True))


hybrid_model.add(Flatten())
hybrid_model.add(Dense(4, activation='softmax'))

hybrid_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 600, 1, 20)        6620
#
#  max_pooling2d_4 (MaxPoolin  (None, 200, 1, 20)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 200, 1, 20)        80
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 200, 1, 20)        0
#
#  conv2d_5 (Conv2D)           (None, 200, 1, 40)        8040
#
#  max_pooling2d_5 (MaxPoolin  (None, 67, 1, 40)         0
#  g2D)
#
#  batch_normalization_6 (Bat  (None, 67, 1, 40)         160
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 67, 1, 40)         0
#
#  conv2d_6 (Conv2D)           (None, 67, 1, 60)         12060
#
#  max_pooling2d_6 (MaxPoolin  (None, 23, 1, 60)         0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 23, 1, 60)         240
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 23, 1, 60)         0
#
#  conv2d_7 (Conv2D)           (None, 23, 1, 100)        30100
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 1, 100)         0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 8, 1, 100)         400
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 8, 1, 100)         0
#
#  time_distributed_4 (TimeDi  (None, 8, 100)            0
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 8, 40)             4040
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 8, 40)             160
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 8, 40)             0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 8, 8)              1568
#
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 63728 (248.94 KB)
# Trainable params: 63208 (246.91 KB)
# Non-trainable params: 520 (2.03 KB)
# _________________________________________________________________

# %%
learning_rate = 1e-3
epochs = 150
cnn_model_optimizer = keras.optimizers.legacy.Adam(learning_rate=learning_rate)

# %%
# Compiling the model
hybrid_model.compile(loss='categorical_crossentropy',
                 optimizer=cnn_model_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_model_results = hybrid_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/150
# 124/124 [==============================] - 5s 28ms/step - loss: 1.4193 - accuracy: 0.2513 - val_loss: 1.3639 - val_accuracy: 0.3150
# Epoch 2/150
# 124/124 [==============================] - 3s 27ms/step - loss: 1.3854 - accuracy: 0.2881 - val_loss: 1.3662 - val_accuracy: 0.3100
# Epoch 3/150
# 124/124 [==============================] - 3s 27ms/step - loss: 1.3573 - accuracy: 0.3207 - val_loss: 1.3447 - val_accuracy: 0.3300
# Epoch 4/150
# 124/124 [==============================] - 3s 27ms/step - loss: 1.3224 - accuracy: 0.3587 - val_loss: 1.3126 - val_accuracy: 0.3600
# Epoch 5/150
# 124/124 [==============================] - 3s 27ms/step - loss: 1.2670 - accuracy: 0.4096 - val_loss: 1.2904 - val_accuracy: 0.3850
# Epoch 6/150
# 124/124 [==============================] - 3s 27ms/step - loss: 1.2228 - accuracy: 0.4404 - val_loss: 1.2082 - val_accuracy: 0.4150
# Epoch 7/150
# 124/124 [==============================] - 3s 28ms/step - loss: 1.2036 - accuracy: 0.4471 - val_loss: 1.1885 - val_accuracy: 0.4350
# Epoch 8/150
# 124/124 [==============================] - 4s 28ms/step - loss: 1.1767 - accuracy: 0.4646 - val_loss: 1.1835 - val_accuracy: 0.4450
# Epoch 9/150
# 124/124 [==============================] - 4s 30ms/step - loss: 1.1508 - accuracy: 0.4809 - val_loss: 1.1965 - val_accuracy: 0.4600
# Epoch 10/150
# 124/124 [==============================] - 4s 29ms/step - loss: 1.1391 - accuracy: 0.4932 - val_loss: 1.2650 - val_accuracy: 0.4250
# Epoch 11/150
# 124/124 [==============================] - 4s 29ms/step - loss: 1.1269 - accuracy: 0.4941 - val_loss: 1.1968 - val_accuracy: 0.4250
# Epoch 12/150
# 124/124 [==============================] - 4s 30ms/step - loss: 1.1068 - accuracy: 0.5128 - val_loss: 1.2189 - val_accuracy: 0.4350
# Epoch 13/150
# 124/124 [==============================] - 4s 29ms/step - loss: 1.0920 - accuracy: 0.5215 - val_loss: 1.1946 - val_accuracy: 0.4850
# Epoch 14/150
# 124/124 [==============================] - 4s 29ms/step - loss: 1.0777 - accuracy: 0.5308 - val_loss: 1.2356 - val_accuracy: 0.4400
# Epoch 15/150
# 124/124 [==============================] - 4s 29ms/step - loss: 1.0465 - accuracy: 0.5534 - val_loss: 1.2499 - val_accuracy: 0.4000
# Epoch 16/150
# 124/124 [==============================] - 4s 31ms/step - loss: 1.0308 - accuracy: 0.5636 - val_loss: 1.2188 - val_accuracy: 0.4400
# Epoch 17/150
# 124/124 [==============================] - 4s 30ms/step - loss: 1.0100 - accuracy: 0.5766 - val_loss: 1.2292 - val_accuracy: 0.4600
# Epoch 18/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.9833 - accuracy: 0.5899 - val_loss: 1.1917 - val_accuracy: 0.4850
# Epoch 19/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.9598 - accuracy: 0.5991 - val_loss: 1.2227 - val_accuracy: 0.4650
# Epoch 20/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.9400 - accuracy: 0.6131 - val_loss: 1.1806 - val_accuracy: 0.4950
# Epoch 21/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.9212 - accuracy: 0.6177 - val_loss: 1.1596 - val_accuracy: 0.4750
# Epoch 22/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.8984 - accuracy: 0.6320 - val_loss: 1.1646 - val_accuracy: 0.5400
# Epoch 23/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.8730 - accuracy: 0.6451 - val_loss: 1.2076 - val_accuracy: 0.4850
# Epoch 24/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.8610 - accuracy: 0.6479 - val_loss: 1.2023 - val_accuracy: 0.4900
# Epoch 25/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.8240 - accuracy: 0.6772 - val_loss: 1.0929 - val_accuracy: 0.5950
# Epoch 26/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.8113 - accuracy: 0.6833 - val_loss: 1.1387 - val_accuracy: 0.5300
# Epoch 27/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.7998 - accuracy: 0.6862 - val_loss: 1.0356 - val_accuracy: 0.5950
# Epoch 28/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.7799 - accuracy: 0.6884 - val_loss: 1.0832 - val_accuracy: 0.5650
# Epoch 29/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.7624 - accuracy: 0.7045 - val_loss: 1.0766 - val_accuracy: 0.6000
# Epoch 30/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.7527 - accuracy: 0.7068 - val_loss: 1.0906 - val_accuracy: 0.5900
# Epoch 31/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.7274 - accuracy: 0.7196 - val_loss: 1.2095 - val_accuracy: 0.5550
# Epoch 32/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.7233 - accuracy: 0.7180 - val_loss: 1.0274 - val_accuracy: 0.6150
# Epoch 33/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.7173 - accuracy: 0.7222 - val_loss: 1.0450 - val_accuracy: 0.6250
# Epoch 34/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.7037 - accuracy: 0.7319 - val_loss: 1.0521 - val_accuracy: 0.6000
# Epoch 35/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.6922 - accuracy: 0.7324 - val_loss: 1.0980 - val_accuracy: 0.6000
# Epoch 36/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.6585 - accuracy: 0.7469 - val_loss: 1.1459 - val_accuracy: 0.5850
# Epoch 37/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.6636 - accuracy: 0.7435 - val_loss: 1.0379 - val_accuracy: 0.6050
# Epoch 38/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.6586 - accuracy: 0.7454 - val_loss: 1.0669 - val_accuracy: 0.6100
# Epoch 39/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6494 - accuracy: 0.7514 - val_loss: 1.1292 - val_accuracy: 0.6100
# Epoch 40/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6382 - accuracy: 0.7548 - val_loss: 0.9729 - val_accuracy: 0.6400
# Epoch 41/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6226 - accuracy: 0.7602 - val_loss: 1.0899 - val_accuracy: 0.6100
# Epoch 42/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6222 - accuracy: 0.7618 - val_loss: 1.0650 - val_accuracy: 0.6200
# Epoch 43/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6069 - accuracy: 0.7718 - val_loss: 1.0752 - val_accuracy: 0.6200
# Epoch 44/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.6010 - accuracy: 0.7670 - val_loss: 1.0369 - val_accuracy: 0.6350
# Epoch 45/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5959 - accuracy: 0.7711 - val_loss: 0.9972 - val_accuracy: 0.6500
# Epoch 46/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5769 - accuracy: 0.7751 - val_loss: 1.0705 - val_accuracy: 0.6200
# Epoch 47/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.5730 - accuracy: 0.7845 - val_loss: 1.0412 - val_accuracy: 0.6100
# Epoch 48/150
# 124/124 [==============================] - 5s 36ms/step - loss: 0.5670 - accuracy: 0.7850 - val_loss: 1.0993 - val_accuracy: 0.5950
# Epoch 49/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.5597 - accuracy: 0.7913 - val_loss: 1.0340 - val_accuracy: 0.6050
# Epoch 50/150
# 124/124 [==============================] - 4s 36ms/step - loss: 0.5481 - accuracy: 0.7923 - val_loss: 1.0851 - val_accuracy: 0.6450
# Epoch 51/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.5506 - accuracy: 0.7923 - val_loss: 1.1972 - val_accuracy: 0.6400
# Epoch 52/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.5411 - accuracy: 0.8011 - val_loss: 0.9134 - val_accuracy: 0.7000
# Epoch 53/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5250 - accuracy: 0.7984 - val_loss: 1.0738 - val_accuracy: 0.6400
# Epoch 54/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.5279 - accuracy: 0.8008 - val_loss: 1.2511 - val_accuracy: 0.5900
# Epoch 55/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5345 - accuracy: 0.8040 - val_loss: 1.1214 - val_accuracy: 0.6200
# Epoch 56/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5206 - accuracy: 0.8030 - val_loss: 1.0731 - val_accuracy: 0.6300
# Epoch 57/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5012 - accuracy: 0.8112 - val_loss: 1.0769 - val_accuracy: 0.6050
# Epoch 58/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5053 - accuracy: 0.8117 - val_loss: 0.9924 - val_accuracy: 0.6400
# Epoch 59/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.4946 - accuracy: 0.8139 - val_loss: 0.9763 - val_accuracy: 0.6550
# Epoch 60/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.5000 - accuracy: 0.8144 - val_loss: 1.1348 - val_accuracy: 0.6050
# Epoch 61/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.4849 - accuracy: 0.8147 - val_loss: 1.1943 - val_accuracy: 0.6150
# Epoch 62/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.4834 - accuracy: 0.8195 - val_loss: 1.0314 - val_accuracy: 0.6650
# Epoch 63/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4951 - accuracy: 0.8135 - val_loss: 1.1522 - val_accuracy: 0.5850
# Epoch 64/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4733 - accuracy: 0.8212 - val_loss: 1.1020 - val_accuracy: 0.6100
# Epoch 65/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4711 - accuracy: 0.8255 - val_loss: 1.0361 - val_accuracy: 0.6750
# Epoch 66/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4592 - accuracy: 0.8280 - val_loss: 1.1054 - val_accuracy: 0.6300
# Epoch 67/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4732 - accuracy: 0.8263 - val_loss: 1.1133 - val_accuracy: 0.6550
# Epoch 68/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4704 - accuracy: 0.8254 - val_loss: 1.0373 - val_accuracy: 0.6350
# Epoch 69/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4638 - accuracy: 0.8310 - val_loss: 1.0543 - val_accuracy: 0.6450
# Epoch 70/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4551 - accuracy: 0.8296 - val_loss: 1.0576 - val_accuracy: 0.6400
# Epoch 71/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4590 - accuracy: 0.8278 - val_loss: 1.1556 - val_accuracy: 0.6100
# Epoch 72/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.4556 - accuracy: 0.8289 - val_loss: 1.1016 - val_accuracy: 0.6700
# Epoch 73/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4352 - accuracy: 0.8336 - val_loss: 1.0301 - val_accuracy: 0.6600
# Epoch 74/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4430 - accuracy: 0.8327 - val_loss: 1.1419 - val_accuracy: 0.6300
# Epoch 75/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4347 - accuracy: 0.8430 - val_loss: 1.1133 - val_accuracy: 0.6400
# Epoch 76/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4323 - accuracy: 0.8379 - val_loss: 1.0585 - val_accuracy: 0.6450
# Epoch 77/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4213 - accuracy: 0.8422 - val_loss: 1.1051 - val_accuracy: 0.6300
# Epoch 78/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4317 - accuracy: 0.8416 - val_loss: 1.0046 - val_accuracy: 0.6550
# Epoch 79/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4356 - accuracy: 0.8335 - val_loss: 0.9835 - val_accuracy: 0.7150
# Epoch 80/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4319 - accuracy: 0.8417 - val_loss: 1.0997 - val_accuracy: 0.6600
# Epoch 81/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4172 - accuracy: 0.8446 - val_loss: 1.1758 - val_accuracy: 0.6400
# Epoch 82/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.4206 - accuracy: 0.8414 - val_loss: 1.1508 - val_accuracy: 0.6500
# Epoch 83/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4149 - accuracy: 0.8449 - val_loss: 1.2025 - val_accuracy: 0.6500
# Epoch 84/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4108 - accuracy: 0.8466 - val_loss: 1.0678 - val_accuracy: 0.6500
# Epoch 85/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4032 - accuracy: 0.8465 - val_loss: 1.0334 - val_accuracy: 0.6850
# Epoch 86/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.4056 - accuracy: 0.8515 - val_loss: 1.1474 - val_accuracy: 0.6300
# Epoch 87/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.4053 - accuracy: 0.8545 - val_loss: 1.0748 - val_accuracy: 0.6800
# Epoch 88/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3947 - accuracy: 0.8558 - val_loss: 1.1296 - val_accuracy: 0.6450
# Epoch 89/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3844 - accuracy: 0.8599 - val_loss: 1.0836 - val_accuracy: 0.6550
# Epoch 90/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3970 - accuracy: 0.8515 - val_loss: 1.1125 - val_accuracy: 0.6350
# Epoch 91/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3919 - accuracy: 0.8538 - val_loss: 1.0839 - val_accuracy: 0.6700
# Epoch 92/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3947 - accuracy: 0.8519 - val_loss: 1.0595 - val_accuracy: 0.6650
# Epoch 93/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3992 - accuracy: 0.8503 - val_loss: 1.1271 - val_accuracy: 0.6450
# Epoch 94/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3846 - accuracy: 0.8541 - val_loss: 1.1472 - val_accuracy: 0.6100
# Epoch 95/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3781 - accuracy: 0.8623 - val_loss: 1.0405 - val_accuracy: 0.6650
# Epoch 96/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3802 - accuracy: 0.8600 - val_loss: 1.0501 - val_accuracy: 0.6450
# Epoch 97/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3731 - accuracy: 0.8589 - val_loss: 1.1737 - val_accuracy: 0.6450
# Epoch 98/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3809 - accuracy: 0.8586 - val_loss: 1.1082 - val_accuracy: 0.6450
# Epoch 99/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3754 - accuracy: 0.8624 - val_loss: 1.1852 - val_accuracy: 0.6250
# Epoch 100/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3737 - accuracy: 0.8596 - val_loss: 1.0783 - val_accuracy: 0.6600
# Epoch 101/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3694 - accuracy: 0.8625 - val_loss: 1.1794 - val_accuracy: 0.6400
# Epoch 102/150
# 124/124 [==============================] - 4s 29ms/step - loss: 0.3700 - accuracy: 0.8667 - val_loss: 1.1137 - val_accuracy: 0.6400
# Epoch 103/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3783 - accuracy: 0.8580 - val_loss: 1.1752 - val_accuracy: 0.6100
# Epoch 104/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3647 - accuracy: 0.8666 - val_loss: 1.1380 - val_accuracy: 0.6250
# Epoch 105/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3559 - accuracy: 0.8695 - val_loss: 1.1509 - val_accuracy: 0.6500
# Epoch 106/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3524 - accuracy: 0.8701 - val_loss: 1.1893 - val_accuracy: 0.6350
# Epoch 107/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3595 - accuracy: 0.8709 - val_loss: 1.1323 - val_accuracy: 0.6350
# Epoch 108/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3602 - accuracy: 0.8675 - val_loss: 1.0408 - val_accuracy: 0.6750
# Epoch 109/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3519 - accuracy: 0.8719 - val_loss: 1.1372 - val_accuracy: 0.6450
# Epoch 110/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3545 - accuracy: 0.8685 - val_loss: 1.1209 - val_accuracy: 0.6400
# Epoch 111/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3584 - accuracy: 0.8687 - val_loss: 1.0159 - val_accuracy: 0.6700
# Epoch 112/150
# 124/124 [==============================] - 4s 30ms/step - loss: 0.3657 - accuracy: 0.8615 - val_loss: 1.1678 - val_accuracy: 0.6700
# Epoch 113/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3447 - accuracy: 0.8728 - val_loss: 1.2766 - val_accuracy: 0.6100
# Epoch 114/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3477 - accuracy: 0.8748 - val_loss: 1.1851 - val_accuracy: 0.6450
# Epoch 115/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3394 - accuracy: 0.8745 - val_loss: 1.1809 - val_accuracy: 0.6500
# Epoch 116/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3491 - accuracy: 0.8723 - val_loss: 1.2177 - val_accuracy: 0.6450
# Epoch 117/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3474 - accuracy: 0.8732 - val_loss: 1.1777 - val_accuracy: 0.6200
# Epoch 118/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3442 - accuracy: 0.8692 - val_loss: 1.1085 - val_accuracy: 0.6550
# Epoch 119/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3408 - accuracy: 0.8730 - val_loss: 1.1895 - val_accuracy: 0.6500
# Epoch 120/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3528 - accuracy: 0.8694 - val_loss: 1.1817 - val_accuracy: 0.6650
# Epoch 121/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3426 - accuracy: 0.8733 - val_loss: 1.1319 - val_accuracy: 0.6700
# Epoch 122/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3367 - accuracy: 0.8752 - val_loss: 1.1040 - val_accuracy: 0.6950
# Epoch 123/150
# 124/124 [==============================] - 4s 31ms/step - loss: 0.3369 - accuracy: 0.8754 - val_loss: 1.1275 - val_accuracy: 0.6850
# Epoch 124/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3380 - accuracy: 0.8711 - val_loss: 1.1479 - val_accuracy: 0.6700
# Epoch 125/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3341 - accuracy: 0.8786 - val_loss: 1.1210 - val_accuracy: 0.6700
# Epoch 126/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3371 - accuracy: 0.8739 - val_loss: 1.0790 - val_accuracy: 0.6800
# Epoch 127/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3357 - accuracy: 0.8753 - val_loss: 1.1251 - val_accuracy: 0.6750
# Epoch 128/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3269 - accuracy: 0.8834 - val_loss: 1.1217 - val_accuracy: 0.6800
# Epoch 129/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3444 - accuracy: 0.8764 - val_loss: 1.2098 - val_accuracy: 0.6600
# Epoch 130/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.3298 - accuracy: 0.8783 - val_loss: 1.1616 - val_accuracy: 0.6600
# Epoch 131/150
# 124/124 [==============================] - 4s 35ms/step - loss: 0.3230 - accuracy: 0.8826 - val_loss: 1.1819 - val_accuracy: 0.6400
# Epoch 132/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3273 - accuracy: 0.8806 - val_loss: 1.1982 - val_accuracy: 0.6450
# Epoch 133/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3215 - accuracy: 0.8771 - val_loss: 1.1717 - val_accuracy: 0.6450
# Epoch 134/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3213 - accuracy: 0.8826 - val_loss: 1.1236 - val_accuracy: 0.6600
# Epoch 135/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3181 - accuracy: 0.8806 - val_loss: 1.2199 - val_accuracy: 0.6600
# Epoch 136/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3225 - accuracy: 0.8854 - val_loss: 1.2656 - val_accuracy: 0.6450
# Epoch 137/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3127 - accuracy: 0.8843 - val_loss: 1.2421 - val_accuracy: 0.6500
# Epoch 138/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3302 - accuracy: 0.8768 - val_loss: 1.2234 - val_accuracy: 0.6600
# Epoch 139/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3262 - accuracy: 0.8783 - val_loss: 1.1701 - val_accuracy: 0.6750
# Epoch 140/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3204 - accuracy: 0.8795 - val_loss: 1.1233 - val_accuracy: 0.6750
# Epoch 141/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3130 - accuracy: 0.8859 - val_loss: 1.1833 - val_accuracy: 0.6950
# Epoch 142/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3200 - accuracy: 0.8828 - val_loss: 1.1695 - val_accuracy: 0.6600
# Epoch 143/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3091 - accuracy: 0.8907 - val_loss: 1.1200 - val_accuracy: 0.6750
# Epoch 144/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3102 - accuracy: 0.8860 - val_loss: 1.0968 - val_accuracy: 0.6850
# Epoch 145/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3185 - accuracy: 0.8825 - val_loss: 1.1877 - val_accuracy: 0.6700
# Epoch 146/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3145 - accuracy: 0.8891 - val_loss: 1.1629 - val_accuracy: 0.6600
# Epoch 147/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3088 - accuracy: 0.8839 - val_loss: 1.1110 - val_accuracy: 0.6800
# Epoch 148/150
# 124/124 [==============================] - 4s 34ms/step - loss: 0.3101 - accuracy: 0.8872 - val_loss: 1.1023 - val_accuracy: 0.6900
# Epoch 149/150
# 124/124 [==============================] - 4s 32ms/step - loss: 0.3125 - accuracy: 0.8874 - val_loss: 1.1657 - val_accuracy: 0.6500
# Epoch 150/150
# 124/124 [==============================] - 4s 33ms/step - loss: 0.3082 - accuracy: 0.8863 - val_loss: 1.1002 - val_accuracy: 0.6750

# %%
# Plotting accuracy trajectory
plt.plot(hybrid_model_results.history['accuracy'])
plt.plot(hybrid_model_results.history['val_accuracy'])
plt.title('Hybrid model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_model_results.history['loss'],'o')
plt.plot(hybrid_model_results.history['val_loss'],'o')
plt.title('Hybrid model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
hybrid_model_score_all_subjects = hybrid_model.evaluate(X_test, y_test, verbose=0)
print("Accuracy Across All Subjects: {score}".format(score=hybrid_model_score_all_subjects[1]))
# Out:
# Accuracy Across All Subjects: 0.690744936466217

# %%
# Test the model against each individual subject group
for i in range(9):
  indices = np.where(person_test[:, 0] == i)
  x = X_test[indices]
  y = y_test[indices]
  score = hybrid_model.evaluate(x, y, verbose=0)
  print("Subject {subject} Accuracy: {score}".format(subject=i, score=score[1]))
# Out:
# Subject 0 Accuracy: 0.6000000238418579
# Subject 1 Accuracy: 0.6399999856948853
# Subject 2 Accuracy: 0.7599999904632568
# Subject 3 Accuracy: 0.7599999904632568
# Subject 4 Accuracy: 0.7021276354789734
# Subject 5 Accuracy: 0.7346938848495483
# Subject 6 Accuracy: 0.6800000071525574
# Subject 7 Accuracy: 0.6800000071525574
# Subject 8 Accuracy: 0.6595744490623474
